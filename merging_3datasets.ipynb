# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
import pandas_profiling

# %%
data_set1 = pd.read_csv("https://raw.githubusercontent.com/shaik4182/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/state-abbrevs.csv")
data_set2 = pd.read_csv("https://raw.githubusercontent.com/shaik4182/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/state-areas.csv")
data_set3 = pd.read_csv("https://raw.githubusercontent.com/shaik4182/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/state-population.csv")

# %%
data_set1
# Out:
#                    state abbreviation
# 0                Alabama           AL
# 1                 Alaska           AK
# 2                Arizona           AZ
# 3               Arkansas           AR
# 4             California           CA
# 5               Colorado           CO
# 6            Connecticut           CT
# 7               Delaware           DE
# 8   District of Columbia           DC
# 9                Florida           FL
# 10               Georgia           GA
# 11                Hawaii           HI
# 12                 Idaho           ID
# 13              Illinois           IL
# 14               Indiana           IN
# 15                  Iowa           IA
# 16                Kansas           KS
# 17              Kentucky           KY
# 18             Louisiana           LA
# 19                 Maine           ME
# 20               Montana           MT
# 21              Nebraska           NE
# 22                Nevada           NV
# 23         New Hampshire           NH
# ...

# %%
data_set1.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
data_set2
# Out:
#                    state  area (sq. mi)
# 0                Alabama          52423
# 1                 Alaska         656425
# 2                Arizona         114006
# 3               Arkansas          53182
# 4             California         163707
# 5               Colorado         104100
# 6            Connecticut           5544
# 7               Delaware           1954
# 8                Florida          65758
# 9                Georgia          59441
# 10                Hawaii          10932
# 11                 Idaho          83574
# 12              Illinois          57918
# 13               Indiana          36420
# 14                  Iowa          56276
# 15                Kansas          82282
# 16              Kentucky          40411
# 17             Louisiana          51843
# 18                 Maine          35387
# 19              Maryland          12407
# 20         Massachusetts          10555
# 21              Michigan          96810
# ...

# %%
data_set2.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
data_set3
# Out:
#      state/region     ages  year   population
# 0              AL  under18  2012    1117489.0
# 1              AL    total  2012    4817528.0
# 2              AL  under18  2010    1130966.0
# 3              AL    total  2010    4785570.0
# 4              AL  under18  2011    1125763.0
# ...           ...      ...   ...          ...
# 2539          USA    total  2010  309326295.0
# 2540          USA  under18  2011   73902222.0
# 2541          USA    total  2011  311582564.0
# 2542          USA  under18  2012   73708179.0
# 2543          USA    total  2012  313873685.0
#
# [2544 rows x 4 columns]

# %%
data_set3.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
data_set1.isna().sum()
# Out:
# state           0
# abbreviation    0
# dtype: int64

# %%
data_set2.isna().sum()
# Out:
# state            0
# area (sq. mi)    0
# dtype: int64

# %%
data_set3.isna().sum()
# Out:
# state/region     0
# ages             0
# year             0
# population      20
# dtype: int64

# %%
da_3=data_set3.rename(columns={'state/region':'abbreviation','ages':'ages','year':'year','population':'population'})
da_3
# Out:
#      abbreviation     ages  year   population
# 0              AL  under18  2012    1117489.0
# 1              AL    total  2012    4817528.0
# 2              AL  under18  2010    1130966.0
# 3              AL    total  2010    4785570.0
# 4              AL  under18  2011    1125763.0
# ...           ...      ...   ...          ...
# 2539          USA    total  2010  309326295.0
# 2540          USA  under18  2011   73902222.0
# 2541          USA    total  2011  311582564.0
# 2542          USA  under18  2012   73708179.0
# 2543          USA    total  2012  313873685.0
#
# [2544 rows x 4 columns]

# %%
da_3
# Out:
#      abbreviation     ages  year   population
# 0              AL  under18  2012    1117489.0
# 1              AL    total  2012    4817528.0
# 2              AL  under18  2010    1130966.0
# 3              AL    total  2010    4785570.0
# 4              AL  under18  2011    1125763.0
# ...           ...      ...   ...          ...
# 2539          USA    total  2010  309326295.0
# 2540          USA  under18  2011   73902222.0
# 2541          USA    total  2011  311582564.0
# 2542          USA  under18  2012   73708179.0
# 2543          USA    total  2012  313873685.0
#
# [2544 rows x 4 columns]

# %%
df4 = pd.merge(data_set1,da_3)

# %%
df4
# Out:
#         state abbreviation     ages  year  population
# 0     Alabama           AL  under18  2012   1117489.0
# 1     Alabama           AL    total  2012   4817528.0
# 2     Alabama           AL  under18  2010   1130966.0
# 3     Alabama           AL    total  2010   4785570.0
# 4     Alabama           AL  under18  2011   1125763.0
# ...       ...          ...      ...   ...         ...
# 2443  Wyoming           WY  under18  1993    137458.0
# 2444  Wyoming           WY    total  1991    459260.0
# 2445  Wyoming           WY  under18  1991    136720.0
# 2446  Wyoming           WY  under18  1990    136078.0
# 2447  Wyoming           WY    total  1990    453690.0
#
# [2448 rows x 5 columns]

# %%
df5=pd.merge(df4,data_set2)

# %%
df5
# Out:
#         state abbreviation     ages  year  population  area (sq. mi)
# 0     Alabama           AL  under18  2012   1117489.0          52423
# 1     Alabama           AL    total  2012   4817528.0          52423
# 2     Alabama           AL  under18  2010   1130966.0          52423
# 3     Alabama           AL    total  2010   4785570.0          52423
# 4     Alabama           AL  under18  2011   1125763.0          52423
# ...       ...          ...      ...   ...         ...            ...
# 2443  Wyoming           WY  under18  1993    137458.0          97818
# 2444  Wyoming           WY    total  1991    459260.0          97818
# 2445  Wyoming           WY  under18  1991    136720.0          97818
# 2446  Wyoming           WY  under18  1990    136078.0          97818
# 2447  Wyoming           WY    total  1990    453690.0          97818
#
# [2448 rows x 6 columns]

# %%
df5.to_csv("state.csv")

# %%
df5.isna()
# Out:
#       state  abbreviation   ages   year  population  area (sq. mi)
# 0     False         False  False  False       False          False
# 1     False         False  False  False       False          False
# 2     False         False  False  False       False          False
# 3     False         False  False  False       False          False
# 4     False         False  False  False       False          False
# ...     ...           ...    ...    ...         ...            ...
# 2443  False         False  False  False       False          False
# 2444  False         False  False  False       False          False
# 2445  False         False  False  False       False          False
# 2446  False         False  False  False       False          False
# 2447  False         False  False  False       False          False
#
# [2448 rows x 6 columns]

# %%
df5.isna().sum()
# Out:
# state            0
# abbreviation     0
# ages             0
# year             0
# population       0
# area (sq. mi)    0
# dtype: int64

# %%
df5.head()
# Out:
#      state abbreviation     ages  year  population  area (sq. mi)
# 0  Alabama           AL  under18  2012   1117489.0          52423
# 1  Alabama           AL    total  2012   4817528.0          52423
# 2  Alabama           AL  under18  2010   1130966.0          52423
# 3  Alabama           AL    total  2010   4785570.0          52423
# 4  Alabama           AL  under18  2011   1125763.0          52423

# %%
df5.tail()
# Out:
#         state abbreviation     ages  year  population  area (sq. mi)
# 2443  Wyoming           WY  under18  1993    137458.0          97818
# 2444  Wyoming           WY    total  1991    459260.0          97818
# 2445  Wyoming           WY  under18  1991    136720.0          97818
# 2446  Wyoming           WY  under18  1990    136078.0          97818
# 2447  Wyoming           WY    total  1990    453690.0          97818

# %%
df5.describe()
# Out:
#               year    population  area (sq. mi)
# count  2448.000000  2.448000e+03    2448.000000
# mean   2001.500000  3.494881e+06   74252.627451
# std       6.923601  5.011334e+06   94929.655186
# min    1990.000000  1.013090e+05      68.000000
# 25%    1995.750000  7.282355e+05   35387.000000
# 50%    2001.500000  1.557804e+06   56276.000000
# 75%    2007.250000  4.406263e+06   84904.000000
# max    2013.000000  3.833252e+07  656425.000000

# %%
df5.describe(include='all')
# Out:
#            state abbreviation   ages         year    population  area (sq. mi)
# count       2448         2448   2448  2448.000000  2.448000e+03    2448.000000
# unique        51           51      2          NaN           NaN            NaN
# top     Illinois           OR  total          NaN           NaN            NaN
# freq          48           48   1224          NaN           NaN            NaN
# mean         NaN          NaN    NaN  2001.500000  3.494881e+06   74252.627451
# std          NaN          NaN    NaN     6.923601  5.011334e+06   94929.655186
# min          NaN          NaN    NaN  1990.000000  1.013090e+05      68.000000
# 25%          NaN          NaN    NaN  1995.750000  7.282355e+05   35387.000000
# 50%          NaN          NaN    NaN  2001.500000  1.557804e+06   56276.000000
# 75%          NaN          NaN    NaN  2007.250000  4.406263e+06   84904.000000
# max          NaN          NaN    NaN  2013.000000  3.833252e+07  656425.000000

# %%
sns.pairplot(df5)

# %%
pandas_profiling.ProfileReport(df5)
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.2.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
sns.heatmap(df5.corr())

# %%
sns.kdeplot(df5.corr())

# %%
df5.corr()
# Out:
#                        year  population  area_(sq._mi)
# year           1.000000e+00    0.044359  -4.994492e-18
# population     4.435937e-02    1.000000   9.459483e-02
# area_(sq._mi) -4.994492e-18    0.094595   1.000000e+00

# %%
x = df5['year']
y= df5['population']

# %%
x
# Out:
# 0       2012
# 1       2012
# 2       2010
# 3       2010
# 4       2011
#         ...
# 2443    1993
# 2444    1991
# 2445    1991
# 2446    1990
# 2447    1990
# Name: year, Length: 2448, dtype: int64

# %%
y
# Out:
# 0       1117489.0
# 1       4817528.0
# 2       1130966.0
# 3       4785570.0
# 4       1125763.0
#           ...
# 2443     137458.0
# 2444     459260.0
# 2445     136720.0
# 2446     136078.0
# 2447     453690.0
# Name: population, Length: 2448, dtype: float64

# %%
plt.plot(x,y)

# %%
from scipy import stats

# %%
slope,intercept,r_value,p_value,std_error=stats.linregress(x,y)

# %%
slope
# Out:
# 32107.520396419448

# %%
intercept
# Out:
# -60768320.60080281

# %%
r_value**2
# Out:
# 0.001967753958435515

# %%
p_value
# Out:
# 0.028182258947705225

# %%
r_value
# Out:
# 0.044359372836363625

# %%
std_error
# Out:
# 14620.607896051459

# %%
plt.figure(figsize=(16,9))
plt.scatter(x,y)
plt.xlabel('year')
plt.ylabel('population')
plt.grid()

# %%
plt.bar(x,y,label='population')

plt.legend()
plt.xlabel('year')
plt.ylabel('population')
plt.title('comparing year and population')

plt.show()

# %%
m=slope
c=intercept

# %%
plt.scatter(x,y)
plt.plot(x,m*x+c,'*r')
